# %%
import os
import numpy as np

# %%
with open("Data/BCICIV_calib_ds1d_cnt.txt") as file:
    i = 0
    for row in file:
        if i in range(2):
            ans = row.split("\t")
            print(ans, end="\n\n")
        else:
            pass
        i += 1
    print("Total number of readings:",i)
# Out:
# ['-36', '-138', '-50', '-34', '-24', '-16', '-59', '-136', '-78', '-30', '-28', '-43', '5', '-21', '-82', '-245', '-30', '-59', '-37', '-25', '-48', '-33', '-103', '-231', '-41', '-51', '-21', '-30', '-23', '-40', '-48', '-85', '-137', '-32', '-19', '-30', '-25', '-43', '9', '-131', '-126', '-21', '-44', '-25', '-26', '-37', '-66', '-117', '-24', '-19', '-24', '-30', '-43', '-16', '-169', '-27', '-58', '-81', '-270\n']
#
# ['-203', '-774', '-280', '-190', '-137', '-90', '-323', '-751', '-441', '-166', '-161', '-238', '33', '-115', '-446', '-1337', '-164', '-331', '-208', '-134', '-257', '-174', '-566', '-1301', '-231', '-283', '-117', '-166', '-121', '-213', '-253', '-456', '-743', '-169', '-95', '-160', '-132', '-225', '60', '-722', '-687', '-110', '-238', '-133', '-136', '-193', '-354', '-636', '-124', '-100', '-131', '-160', '-229', '-81', '-940', '-143', '-308', '-438', '-1479\n']
#
# Total number of readings: 190473

# %%
with open("Data/BCICIV_calib_ds1d_mrk.txt") as file:
    i = 0
    for row in file:
        i += 1
        print(row)
    print(i)
# Out:
# 2.095000e+03	1.000000e+00
#
# 2.895000e+03	1.000000e+00
#
# 3.695000e+03	1.000000e+00
#
# 4.495000e+03	-1.000000e+00
#
# 5.295000e+03	1.000000e+00
#
# 6.095000e+03	1.000000e+00
#
# 6.895000e+03	1.000000e+00
#
# 7.695000e+03	-1.000000e+00
#
# 8.495000e+03	1.000000e+00
#
# 9.295000e+03	1.000000e+00
#
# 1.009500e+04	1.000000e+00
#
# 1.089500e+04	-1.000000e+00
#
# 1.169500e+04	1.000000e+00
#
# 1.249500e+04	-1.000000e+00
#
# 1.329500e+04	-1.000000e+00
#
# 1.629400e+04	-1.000000e+00
#
# 1.709400e+04	1.000000e+00
#
# 1.789400e+04	-1.000000e+00
#
# 1.869400e+04	-1.000000e+00
#
# 1.949400e+04	-1.000000e+00
#
# 2.029400e+04	1.000000e+00
#
# 2.109400e+04	1.000000e+00
#
# 2.189400e+04	1.000000e+00
#
# 2.269400e+04	-1.000000e+00
#
# 2.349400e+04	1.000000e+00
#
# 2.429500e+04	-1.000000e+00
#
# 2.509500e+04	-1.000000e+00
#
# 2.589500e+04	-1.000000e+00
#
# 2.669500e+04	1.000000e+00
#
# 2.749500e+04	-1.000000e+00
#
# 3.049400e+04	1.000000e+00
#
# 3.129400e+04	1.000000e+00
#
# ...

# %%
with open("Data/BCICIV_calib_ds1d_nfo.txt") as file:
    i = 0
    for row in file:
        i += 1
        print(row)
    print(i)
# Out:
# fs: 100
#
# classes: left, right
#
# clab: AF3, AF4, F5, F3, F1, Fz, F2, F4, F6, FC5, FC3, FC1, FCz, FC2, FC4, FC6, CFC7, CFC5, CFC3, CFC1, CFC2, CFC4, CFC6, CFC8, T7, C5, C3, C1, Cz, C2, C4, C6, T8, CCP7, CCP5, CCP3, CCP1, CCP2, CCP4, CCP6, CCP8, CP5, CP3, CP1, CPz, CP2, CP4, CP6, P5, P3, P1, Pz, P2, P4, P6, PO1, PO2, O1, O2
#
# xpos: -0.20109, 0.20109, -0.485475, -0.328947, -0.165352, 0, 0.165352, 0.328947, 0.485475, -0.605915, -0.399196, -0.197659, 0, 0.197659, 0.399196, 0.605915, -0.748347, -0.52473, -0.309639, -0.102263, 0.102263, 0.309639, 0.52473, 0.748347, -0.877193, -0.645691, -0.421549, -0.207738, 0, 0.207738, 0.421549, 0.645691, 0.877193, -0.748347, -0.52473, -0.309639, -0.102263, 0.102263, 0.309639, 0.52473, 0.748347, -0.605915, -0.399196, -0.197659, 0, 0.197659, 0.399196, 0.605915, -0.485475, -0.328947, -0.165352, 0, 0.165352, 0.328947, 0.485475, -0.103959, 0.103959, -0.171132, 0.171132
#
# ...
